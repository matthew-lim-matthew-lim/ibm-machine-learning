# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('https://datasocibmproject.s3.ap-southeast-2.amazonaws.com/structured_data/capital_project_schedules_and_budgets_1.csv')

# %%
# First first few rows of dataset
df.head()
# Out:
#    Unnamed: 0  project_geographic_district project_building_identifier  \
# 0           0                           10                        X254
# 1           1                           10                        X254
# 2           2                           10                        X254
# 3           3                           10                        X254
# 4           4                           10                        X254
#
#   project_school_name   project_type  \
# 0    I.S. 254 - BRONX        SCA CIP
# 1    I.S. 254 - BRONX        SCA CIP
# 2    I.S. 254 - BRONX  SCA CIP RESOA
# 3    I.S. 254 - BRONX  SCA CIP RESOA
# 4    I.S. 254 - BRONX  SCA CIP RESOA
#
#                                project_description project_phase_name  \
# 0                                     FACADE/ROOFS       Construction
# 1                                     FACADE/ROOFS            CM, F&E
# 2  FY16 RESO A IP SURVEILLANCE CAMERA INSTALLATION              Scope
# 3  FY16 RESO A IP SURVEILLANCE CAMERA INSTALLATION             Design
# 4  FY16 RESO A IP SURVEILLANCE CAMERA INSTALLATION       Construction
#
#   project_status_name project_phase_actual_start_date  \
# 0         In-Progress                      07/07/2016
# 1         In-Progress                      07/07/2016
# 2            Complete                      07/27/2017
# 3         In-Progress                      08/04/2017
# 4                 PNS                             PNS
#
#   project_phase_planned_end_date project_phase_actual_end_date  \
# 0                     03/28/2018                           NaN
# 1                     03/28/2018                           NaN
# 2                     11/27/2017                    08/03/2017
# 3                     02/05/2018                           NaN
# 4                            PNS                           PNS
#
#   project_budget_amount  \
# 0               4050000
# 1                252000
# 2                     0
# 3                 19110
# 4                280280
#
#    final_estimate_of_actual_costs_through_end_of_phase_amount  \
# 0                                          4229193.0
# 1                                           489326.0
# 2                                             1792.0
# 3                                            17318.0
# 4                                           280280.0
#
#    total_phase_actual_spending_amount                 dsf_number_s  failure
# 0                           3791127.0  DSF: 0000821031, 0000822210    False
# 1                            485620.0  DSF: 0000821031, 0000822210    False
# 2                              1792.0              DSF: 0000823560    False
# 3                              7169.0              DSF: 0000823560     True
# 4                               951.0              DSF: 0000823560    False

# %%
# Missing values

# %%
df.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Encode the categorical data so that we can more easily work with it

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform the project_building_identifier column
df['project_building_identifier_encoded'] = label_encoder.fit_transform(df['project_building_identifier'])
df['project_building_identifier_encoded'] = label_encoder.fit_transform(df['project_building_identifier'])

# %%
# Check the values for a specific building
df[df['project_building_identifier_encoded'] == 2]
# Out:
#       Unnamed: 0  project_geographic_district project_building_identifier  \
# 1767        1767                           13                        K003
# 1768        1768                           13                        K003
# 1769        1769                           13                        K003
# 1770        1770                           13                        K003
# 1771        1771                           13                        K003
# 1772        1772                           13                        K003
# 1773        1773                           13                        K003
# 1774        1774                           13                        K003
# 1775        1775                           13                        K003
#
#      project_school_name   project_type  \
# 1767   P.S. 3 - BROOKLYN        SCA CIP
# 1768   P.S. 3 - BROOKLYN        SCA CIP
# 1769   P.S. 3 - BROOKLYN        SCA CIP
# 1770   P.S. 3 - BROOKLYN        SCA CIP
# 1771   P.S. 3 - BROOKLYN  SCA CIP RESOA
# 1772   P.S. 3 - BROOKLYN  SCA CIP RESOA
# 1773   P.S. 3 - BROOKLYN  SCA CIP RESOA
# 1774   P.S. 3 - BROOKLYN  SCA CIP RESOA
# 1775   P.S. 3 - BROOKLYN        SCA IEH
#
#                            project_description project_phase_name  \
# 1767  PLANYC BOILER CNVRSN/PLANYC CLIMATE CTRL              Scope
# 1768  PLANYC BOILER CNVRSN/PLANYC CLIMATE CTRL             Design
# 1769  PLANYC BOILER CNVRSN/PLANYC CLIMATE CTRL       Construction
# 1770  PLANYC BOILER CNVRSN/PLANYC CLIMATE CTRL            CM, F&E
# 1771            FY18 RESO A MOBILE SCIENCE LAB              Scope
# 1772            FY18 RESO A MOBILE SCIENCE LAB             Design
# 1773            FY18 RESO A MOBILE SCIENCE LAB       Construction
# 1774            FY18 RESO A MOBILE SCIENCE LAB            CM, F&E
# 1775  IEH PO18-RM 202 RIGHT SIDE FROM ENTRANCE       Construction
#
#      project_status_name project_phase_actual_start_date  \
# 1767            Complete                      07/02/2014
# 1768            Complete                      09/02/2014
# 1769            Complete                      02/26/2016
# 1770            Complete                      02/26/2016
# 1771                 PNS                             PNS
# 1772                 PNS                             PNS
# 1773                 PNS                             PNS
# 1774                 PNS                             PNS
# 1775         In-Progress                      09/25/2017
#
#      project_phase_planned_end_date project_phase_actual_end_date  \
# 1767                     12/04/2014                    08/12/2014
# 1768                     02/05/2015                    01/28/2015
# 1769                     08/18/2017                    08/18/2017
# 1770                     08/18/2017                    08/18/2017
# 1771                            PNS                           PNS
# 1772                            PNS                           PNS
# 1773                            PNS                           PNS
# 1774                            PNS                           PNS
# 1775                            IEH                           NaN
#
#      project_budget_amount  \
# 1767                 87177
# 1768                348708
# 1769               6538275
# 1770                406826
# 1771                     0
# 1772                  9000
# 1773                132000
# 1774                  9000
# 1775                   IEH
#
#       final_estimate_of_actual_costs_through_end_of_phase_amount  \
# 1767                                            59774.0
# 1768                                           137367.0
# 1769                                          6049631.0
# 1770                                           352085.0
# 1771                                                0.0
# 1772                                             9000.0
# 1773                                           132000.0
# 1774                                             9000.0
# 1775                                            17360.0
#
#       total_phase_actual_spending_amount                 dsf_number_s  \
# 1767                             59774.0  DSF: 0000798244, 0000798245
# 1768                            137367.0  DSF: 0000798244, 0000798245
# 1769                           5736006.0  DSF: 0000798244, 0000798245
# 1770                            351583.0  DSF: 0000798244, 0000798245
# 1771                                 0.0              DSF: 0000866686
# 1772                                 0.0              DSF: 0000866686
# 1773                                 0.0              DSF: 0000866686
# 1774                                 0.0              DSF: 0000866686
# 1775                              4246.0              DSF: 0000048765
#
#       failure  project_building_identifier_encoded
# 1767    False                                    2
# 1768    False                                    2
# 1769    False                                    2
# 1770    False                                    2
# 1771     True                                    2
# 1772    False                                    2
# 1773    False                                    2
# 1774    False                                    2
# 1775    False                                    2

# %%
# Remove the 'DSF:' text from entries with the 'dsf_number_s' column
# Split entries that have multiple DSF entries in the 'dsf_number_s' column. 

df['dsf_number_s'] = df['dsf_number_s'].str.replace('DSF: ', '')
df['dsf_number_s'] = df['dsf_number_s'].str.split(', ')
df = df.explode('dsf_number_s')

df.reset_index(drop=True, inplace=True)

df

# For example, we will split 'DFS: 0000821031, 0000822210' into two seperate rows
# Out:
#        Unnamed: 0  project_geographic_district project_building_identifier  \
# 0               0                           10                        X254
# 1               0                           10                        X254
# 2               1                           10                        X254
# 3               1                           10                        X254
# 4               2                           10                        X254
# ...           ...                          ...                         ...
# 11190        8180                           32                        K842
# 11191        8181                           32                        K865
# 11192        8182                           32                        K865
# 11193        8183                           32                        K865
# 11194        8184                           32                        K865
#
#         project_school_name          project_type  \
# 0          I.S. 254 - BRONX               SCA CIP
# 1          I.S. 254 - BRONX               SCA CIP
# 2          I.S. 254 - BRONX               SCA CIP
# 3          I.S. 254 - BRONX               SCA CIP
# 4          I.S. 254 - BRONX         SCA CIP RESOA
# ...                     ...                   ...
# 11190    P.S. 45 - BROOKLYN  DOE - Skilled Trades
# 11191  BUSHWICK LEADERS - K               SCA CIP
# 11192  BUSHWICK LEADERS - K               SCA CIP
# 11193  BUSHWICK LEADERS - K               SCA CIP
# 11194  BUSHWICK LEADERS - K               SCA CIP
#
#                                    project_description project_phase_name  \
# 0                                         FACADE/ROOFS       Construction
# 1                                         FACADE/ROOFS       Construction
# 2                                         FACADE/ROOFS            CM, F&E
# 3                                         FACADE/ROOFS            CM, F&E
# 4      FY16 RESO A IP SURVEILLANCE CAMERA INSTALLATION              Scope
# ...                                                ...                ...
# 11190                             REPLACE (8) UNIVENTS       Construction
# 11191                         CERTIFICATE OF OCCUPANCY              Scope
# 11192                         CERTIFICATE OF OCCUPANCY             Design
# 11193                         CERTIFICATE OF OCCUPANCY       Construction
# 11194                         CERTIFICATE OF OCCUPANCY            CM, F&E
#
#       project_status_name project_phase_actual_start_date  \
# 0             In-Progress                      07/07/2016
# 1             In-Progress                      07/07/2016
# 2             In-Progress                      07/07/2016
# 3             In-Progress                      07/07/2016
# 4                Complete                      07/27/2017
# ...                   ...                             ...
# 11190         In-Progress                      02/09/2017
# 11191            Complete                      06/18/2013
# 11192         In-Progress                      11/19/2013
# 11193                 PNS                             PNS
# 11194                 PNS                             PNS
#
#       project_phase_planned_end_date project_phase_actual_end_date  \
# 0                         03/28/2018                           NaN
# 1                         03/28/2018                           NaN
# 2                         03/28/2018                           NaN
# 3                         03/28/2018                           NaN
# 4                         11/27/2017                    08/03/2017
# ...                              ...                           ...
# 11190                           DOES                           NaN
# 11191                     12/02/2013                    11/18/2013
# 11192                     05/22/2014                           NaN
# 11193                            PNS                           PNS
# 11194                            PNS                           PNS
#
#       project_budget_amount  \
# 0                   4050000
# 1                   4050000
# 2                    252000
# 3                    252000
# 4                         0
# ...                     ...
# 11190                  DOES
# 11191                 93274
# 11192                373096
# 11193               6995548
# 11194                435279
#
#        final_estimate_of_actual_costs_through_end_of_phase_amount  \
# 0                                              4229193.0
# 1                                              4229193.0
# 2                                               489326.0
# 3                                               489326.0
# 4                                                 1792.0
# ...                                                  ...
# 11190                                           228528.0
# 11191                                           124725.0
# 11192                                           495448.0
# 11193                                          6995548.0
# 11194                                           435279.0
#
#        total_phase_actual_spending_amount dsf_number_s  failure  \
# 0                               3791127.0   0000821031    False
# 1                               3791127.0   0000822210    False
# 2                                485620.0   0000821031    False
# 3                                485620.0   0000822210    False
# 4                                  1792.0   0000823560    False
# ...                                   ...          ...      ...
# 11190                            122258.0   0000851654    False
# 11191                            118749.0   0000776207    False
# 11192                            338602.0   0000776207     True
# 11193                            107204.0   0000776207    False
# 11194                             29715.0   0000776207    False
#
#        project_building_identifier_encoded
# 0                                     1134
# 1                                     1134
# 2                                     1134
# 3                                     1134
# 4                                     1134
# ...                                    ...
# 11190                                  378
# 11191                                  387
# 11192                                  387
# 11193                                  387
# 11194                                  387
#
# [11195 rows x 17 columns]

# %%
# See if multiple rows can share the same 'dsf_number_s' 
df[df['dsf_number_s'] == '0000821031']

# Seems to display different stages of a particular project, DFS: 0000821031
# Out:
#       Unnamed: 0  project_geographic_district project_building_identifier  \
# 0              0                           10                        X254
# 2              1                           10                        X254
# 4704        3426                           10                        X254
# 4706        3427                           10                        X254
#
#      project_school_name project_type project_description project_phase_name  \
# 0       I.S. 254 - BRONX      SCA CIP        FACADE/ROOFS       Construction
# 2       I.S. 254 - BRONX      SCA CIP        FACADE/ROOFS            CM, F&E
# 4704    I.S. 254 - BRONX      SCA CIP        FACADE/ROOFS              Scope
# 4706    I.S. 254 - BRONX      SCA CIP        FACADE/ROOFS             Design
#
#      project_status_name project_phase_actual_start_date  \
# 0            In-Progress                      07/07/2016
# 2            In-Progress                      07/07/2016
# 4704            Complete                      01/29/2015
# 4706            Complete                      07/24/2015
#
#      project_phase_planned_end_date project_phase_actual_end_date  \
# 0                        03/28/2018                           NaN
# 2                        03/28/2018                           NaN
# 4704                     06/15/2015                    06/01/2015
# 4706                     12/28/2015                    01/08/2016
#
#      project_budget_amount  \
# 0                  4050000
# 2                   252000
# 4704                 54000
# 4706                216000
#
#       final_estimate_of_actual_costs_through_end_of_phase_amount  \
# 0                                             4229193.0
# 2                                              489326.0
# 4704                                            97522.0
# 4706                                           248955.0
#
#       total_phase_actual_spending_amount dsf_number_s  failure  \
# 0                              3791127.0   0000821031    False
# 2                               485620.0   0000821031    False
# 4704                             90852.0   0000821031    False
# 4706                            199945.0   0000821031    False
#
#       project_building_identifier_encoded
# 0                                    1134
# 2                                    1134
# 4704                                 1134
# 4706                                 1134

# %%
df[df['dsf_number_s'] == '0000822210']

# Display different stages of a particular project, DFS: 0000822210
# The output is exactly identical to the search for project DFS: 0000821031. This could mean that the split() was unneccessary.
# Out:
#       Unnamed: 0  project_geographic_district project_building_identifier  \
# 1              0                           10                        X254
# 3              1                           10                        X254
# 4705        3426                           10                        X254
# 4707        3427                           10                        X254
#
#      project_school_name project_type project_description project_phase_name  \
# 1       I.S. 254 - BRONX      SCA CIP        FACADE/ROOFS       Construction
# 3       I.S. 254 - BRONX      SCA CIP        FACADE/ROOFS            CM, F&E
# 4705    I.S. 254 - BRONX      SCA CIP        FACADE/ROOFS              Scope
# 4707    I.S. 254 - BRONX      SCA CIP        FACADE/ROOFS             Design
#
#      project_status_name project_phase_actual_start_date  \
# 1            In-Progress                      07/07/2016
# 3            In-Progress                      07/07/2016
# 4705            Complete                      01/29/2015
# 4707            Complete                      07/24/2015
#
#      project_phase_planned_end_date project_phase_actual_end_date  \
# 1                        03/28/2018                           NaN
# 3                        03/28/2018                           NaN
# 4705                     06/15/2015                    06/01/2015
# 4707                     12/28/2015                    01/08/2016
#
#      project_budget_amount  \
# 1                  4050000
# 3                   252000
# 4705                 54000
# 4707                216000
#
#       final_estimate_of_actual_costs_through_end_of_phase_amount  \
# 1                                             4229193.0
# 3                                              489326.0
# 4705                                            97522.0
# 4707                                           248955.0
#
#       total_phase_actual_spending_amount dsf_number_s  failure  \
# 1                              3791127.0   0000822210    False
# 3                               485620.0   0000822210    False
# 4705                             90852.0   0000822210    False
# 4707                            199945.0   0000822210    False
#
#       project_building_identifier_encoded
# 1                                    1134
# 3                                    1134
# 4705                                 1134
# 4707                                 1134

# %%
# Check other dfs values to see how data entries can vary for each dfs_number_s
df[df['dsf_number_s'] == '0000851654']

# Only 1 row, with numerous DOES and NaN values.
# Out:
#        Unnamed: 0  project_geographic_district project_building_identifier  \
# 11190        8180                           32                        K842
#
#       project_school_name          project_type   project_description  \
# 11190  P.S. 45 - BROOKLYN  DOE - Skilled Trades  REPLACE (8) UNIVENTS
#
#       project_phase_name project_status_name project_phase_actual_start_date  \
# 11190       Construction         In-Progress                      02/09/2017
#
#       project_phase_planned_end_date project_phase_actual_end_date  \
# 11190                           DOES                           NaN
#
#       project_budget_amount  \
# 11190                  DOES
#
#        final_estimate_of_actual_costs_through_end_of_phase_amount  \
# 11190                                           228528.0
#
#        total_phase_actual_spending_amount dsf_number_s  failure  \
# 11190                            122258.0   0000851654    False
#
#        project_building_identifier_encoded
# 11190                                  378

# %%
df[df['dsf_number_s'] == '0000776207']

# 4 rows with several PNS values.
# The project has:
# Started and Completed scope.
# Started Design, and not completed Design.
# Is PNS for Construction, CM/F&E
# Out:
#        Unnamed: 0  project_geographic_district project_building_identifier  \
# 11191        8181                           32                        K865
# 11192        8182                           32                        K865
# 11193        8183                           32                        K865
# 11194        8184                           32                        K865
#
#         project_school_name project_type       project_description  \
# 11191  BUSHWICK LEADERS - K      SCA CIP  CERTIFICATE OF OCCUPANCY
# 11192  BUSHWICK LEADERS - K      SCA CIP  CERTIFICATE OF OCCUPANCY
# 11193  BUSHWICK LEADERS - K      SCA CIP  CERTIFICATE OF OCCUPANCY
# 11194  BUSHWICK LEADERS - K      SCA CIP  CERTIFICATE OF OCCUPANCY
#
#       project_phase_name project_status_name project_phase_actual_start_date  \
# 11191              Scope            Complete                      06/18/2013
# 11192             Design         In-Progress                      11/19/2013
# 11193       Construction                 PNS                             PNS
# 11194            CM, F&E                 PNS                             PNS
#
#       project_phase_planned_end_date project_phase_actual_end_date  \
# 11191                     12/02/2013                    11/18/2013
# 11192                     05/22/2014                           NaN
# 11193                            PNS                           PNS
# 11194                            PNS                           PNS
#
#       project_budget_amount  \
# 11191                 93274
# 11192                373096
# 11193               6995548
# 11194                435279
#
#        final_estimate_of_actual_costs_through_end_of_phase_amount  \
# 11191                                           124725.0
# 11192                                           495448.0
# 11193                                          6995548.0
# 11194                                           435279.0
#
#        total_phase_actual_spending_amount dsf_number_s  failure  \
# 11191                            118749.0   0000776207    False
# 11192                            338602.0   0000776207     True
# 11193                            107204.0   0000776207    False
# 11194                             29715.0   0000776207    False
#
#        project_building_identifier_encoded
# 11191                                  387
# 11192                                  387
# 11193                                  387
# 11194                                  387

# %%
df[df['project_phase_actual_end_date'] == 'FTK']

# Only 1 project has 'FTK' end date, so it is likely an error
# Out:
#      Unnamed: 0  project_geographic_district project_building_identifier  \
# 774         610                           11                        X498
#
#          project_school_name         project_type  \
# 774  P.S. / I.S. 498 - BRONX  Fast Track Projects
#
#                 project_description project_phase_name project_status_name  \
# 774  FY17 RESO A ROOFTOP PLAYGROUND       Construction                 PNS
#
#     project_phase_actual_start_date project_phase_planned_end_date  \
# 774                             FTK                            FTK
#
#     project_phase_actual_end_date project_budget_amount  \
# 774                           FTK                   FTK
#
#      final_estimate_of_actual_costs_through_end_of_phase_amount  \
# 774                                           100000.0
#
#      total_phase_actual_spending_amount dsf_number_s  failure  \
# 774                                 0.0   0000845557     True
#
#      project_building_identifier_encoded
# 774                                 1171

# %%
# Look at distinct values to try and see which metrics we can use to find a correlation
categorical_features = df.select_dtypes(include=[object]).columns

for col in categorical_features:
    unique_values = df[col].unique()
    num_values = len(unique_values)
    print(f'{num_values} distinct values in {col}:\n {unique_values}')
# Out:
# 1196 distinct values in project_building_identifier:
#  ['X254' 'X279' 'X283' ... 'K677' 'K799' 'K842']
# 1483 distinct values in project_school_name:
#  ['I.S. 254 - BRONX' 'P.S. 279 - BRONX' 'I.S. 228 - BRONX' ...
#  'ACAD. FOR ENVIRON. LDRSHP - K' 'P.S. 677 - BROOKLYN'
#  'ALC - BROOKLYN CHOICES']
# 20 distinct values in project_type:
#  ['SCA CIP' 'SCA CIP RESOA' 'DIIT - RESOA' 'DOE- RESOA'
#  'SCA Furniture & Equi' 'Trust For Public Lan' 'SCA Capacity'
#  'DOE - Skilled Trades' 'SCA IEH' 'DOE - Lead Paint' 'PRE-K'
#  'DIIT - PBX Telephone' 'DIIT - Project Conne' 'Fast Track Projects'
#  'DCAS/NYPA' 'SCA Lease Site Impro' 'SCA Emergency Lighti' 'RCT CIP'
#  'SCA Emergency Respon' 'DOE Managed PREK']
# 1363 distinct values in project_description:
#  ['FACADE/ROOFS' 'FY16 RESO A IP SURVEILLANCE CAMERA INSTALLATION'
#  'FY17 RESO A TECHNOLOGY' ... 'EXT MASONRY/WINDOWS/PARAPETS/ROOFS'
#  'REPLACE (8) UNIVENTS' 'CERTIFICATE OF OCCUPANCY']
# 9 distinct values in project_phase_name:
#  ['Construction' 'CM, F&E' 'Scope' 'Design' 'Purch & Install' 'F&E'
#  'CM,Art,F&E' 'CM' nan]
# 3 distinct values in project_status_name:
#  ['In-Progress' 'Complete' 'PNS']
# 1069 distinct values in project_phase_actual_start_date:
#  ['07/07/2016' '07/27/2017' '08/04/2017' ... '05/15/2016' '06/24/2016'
#  '06/18/2013']
# 1168 distinct values in project_phase_planned_end_date:
#  ['03/28/2018' '11/27/2017' '02/05/2018' ... '11/04/2015' '12/02/2013'
#  '05/22/2014']
# 889 distinct values in project_phase_actual_end_date:
#  [nan '08/03/2017' 'PNS' '09/14/2017' '02/13/2017' '12/18/2017'
#  '11/13/2017' '07/27/2017' '09/10/2014' '04/28/2015' '06/21/2013'
#  '02/03/2014' '01/17/2017' '04/20/2017' '05/20/2013' '11/06/2013'
#  '01/25/2017' '04/20/2016' '10/14/2016' '07/01/2017' '08/09/2017'
#  '09/10/2013' '03/10/2015' '03/03/2014' '09/23/2014' '11/30/2017'
#  '04/02/2015' '05/13/2015' '12/30/2015' '09/05/2017' '05/01/2015'
#  '09/29/2015' '06/13/2017' '12/07/2017' '07/15/2017' '08/04/2017'
#  '12/11/2017' '10/19/2012' '11/08/2013' '01/30/2017' '07/27/2015'
#  '01/24/2014' '11/22/2016' '08/10/2012' '02/25/2013' '06/04/2014'
#  '10/31/2014' '02/11/2014' '04/19/2016' '07/07/2016' '10/14/2017'
#  '01/05/2017' '11/24/2014' '04/07/2015' '12/06/2016' '04/30/2014'
#  '01/22/2014' '10/24/2014' '06/23/2015' '09/08/2014' '09/30/2016'
#  '08/18/2015' '08/04/2016' '08/13/2014' '01/28/2013' '05/19/2014'
#  '02/08/2012' '03/14/2013' '10/27/2015' '10/19/2016' '06/30/2014'
#  '09/22/2017' '07/30/2014' '05/18/2015' '01/14/2016' '06/11/2013'
#  '06/09/2015' '01/23/2017' '03/09/2016' '02/18/2015' '12/12/2014'
#  '02/07/2017' '10/08/2015' '06/21/2016' '12/24/2015' '03/30/2016'
#  '12/22/2016' '04/25/2017' '10/20/2008' '03/22/2010' '02/11/2013'
#  '08/27/2009' '03/17/2017' '11/05/2014' '08/21/2015' '02/15/2012'
#  '05/08/2012' '01/28/2014' '02/10/2014' '07/24/2014' '04/18/2016'
#  '05/03/2017' '11/14/2014' '10/25/2016' '02/14/2017' '01/21/2015'
#  '07/06/2015' '09/30/2014' '12/11/2014' '06/25/2015' '03/05/2013'
#  '04/29/2015' '08/08/2016' '09/02/2014' '02/25/2015' '08/22/2016'
#  '10/09/2014' '08/07/2015' '08/01/2016' '11/15/2011' '05/09/2012'
#  '09/13/2013' '12/28/2015' '01/27/2012' '10/04/2012' '04/11/2017'
#  '11/19/2014' '06/04/2015' '11/16/2012' '04/23/2013' '12/30/2016'
#  '08/16/2016' '11/13/2013' '08/01/2014' '11/04/2014' '08/13/2015'
#  '01/12/2016' '04/16/2015' '05/12/2014' '03/22/2016' '07/17/2014'
#  '11/10/2016' '03/31/2016' '02/23/2015' '09/24/2015' '01/12/2017'
#  '09/11/2012' '04/16/2013' '10/20/2014' '05/07/2015' '05/23/2017'
#  '10/11/2013' '12/07/2015' '05/27/2016' '10/03/2016' '09/29/2016'
#  '01/30/2014' '11/18/2013']
# 3613 distinct values in project_budget_amount:
#  ['4050000' '252000' '0' ... '373096' '6995548' '435279']
# 4308 distinct values in dsf_number_s:
#  ['0000821031' '0000822210' '0000823560' ... '0000843223' '0000851654'
#  '0000776207']

# %%
# Select the columns that need to be encoded
categorical_columns = [
    'project_geographic_district', 'project_building_identifier', 'project_school_name',
    'project_type', 'project_description', 'project_phase_name', 'project_status_name'
]

# Encode categorical columns
label_encoders = {}
for column in categorical_columns:
    le = LabelEncoder()
    df[column] = le.fit_transform(df[column])
    label_encoders[column] = le

correlation_matrix = df.corr()

plt.figure(figsize=(12, 10))
plt.imshow(correlation_matrix, cmap='viridis', aspect='auto')

# Add color bar
plt.colorbar()

# Set x and y ticks
plt.xticks(ticks=np.arange(len(correlation_matrix.columns)), labels=correlation_matrix.columns, rotation=90)
plt.yticks(ticks=np.arange(len(correlation_matrix.index)), labels=correlation_matrix.index)

plt.title('Heatmap of Correlation Matrix')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 14
#      11     df[column] = le.fit_transform(df[column])
#      12     label_encoders[column] = le
# ---> 14 correlation_matrix = df.corr()
#      16 plt.figure(figsize=(12, 10))
#      17 plt.imshow(correlation_matrix, cmap='viridis', aspect='auto')
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: '07/07/2016'
