# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
def get_unique_values_with_counts(dataframe, column_name):
    """
    This function returns a dictionary with unique values in a specified column of a dataframe
    and their corresponding counts.
    
    Parameters:
    dataframe (pd.DataFrame): The dataframe containing the data.
    column_name (str): The name of the column to extract unique values and counts from.
    
    Returns:
    dict: A dictionary where keys are unique values and values are their counts.
    """
    value_counts = dataframe[column_name].value_counts()
    return value_counts.to_dict()

# Function to find keywords in specified columns
def find_keywords(row, columns, keywords):
    found_keywords = []
    for column in columns:
        for keyword in keywords:
            if pd.notna(row[column]) and keyword in row[column]:
                found_keywords.append(keyword)
    return found_keywords

# %%
df = pd.read_csv("https://datasocibmproject.s3.ap-southeast-2.amazonaws.com/structured_data/capital_project_schedules_and_budgets_1.csv")
df = df.drop(df.columns[0], axis=1)

df = df[df['project_status_name'] == 'Complete']
df.to_csv('ibm_complete.csv', index=False)
df = df.drop(columns=['project_status_name'])

df.shape
# Out:
# (2981, 14)

# %%
get_unique_values_with_counts(df, 'failure')
# Out:
# {False: 2773, True: 208}

# %%
# Checking for missing values in the dataset
missing_values = df.isnull().sum()
missing_values

df['project_phase_name'] = df['project_phase_name'].fillna('Unknown')

# Verify if the missing values have been handled
missing_values_after = df.isnull().sum()
missing_values_after
# Out:
# project_geographic_district                                   0
# project_building_identifier                                   0
# project_school_name                                           0
# project_type                                                  0
# project_description                                           0
# project_phase_name                                            0
# project_phase_actual_start_date                               0
# project_phase_planned_end_date                                0
# project_phase_actual_end_date                                 0
# project_budget_amount                                         0
# final_estimate_of_actual_costs_through_end_of_phase_amount    0
# total_phase_actual_spending_amount                            0
# dsf_number_s                                                  0
# failure                                                       0
# dtype: int64

# %%
# Calculate the failure rate for each project type
failure_rate = df.groupby('project_phase_name')['failure'].mean()

# Sort the failure rate
failure_rate = failure_rate.sort_values(ascending=False)

# Bar chart
plt.figure(figsize=(12, 8))
failure_rate.plot(kind='bar', color='skyblue')
plt.title('Failure Rate by Project Phase (where project status == "Complete")')
plt.xlabel('Project Type')
plt.ylabel('Failure Rate')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# %%
# df[(df['project_phase_name'] == 'Scope') & (df['failure'] == True)]

# %%
project_types = [
    "SCA", "CIP", "DIIT", "DOE", "DOES", "DOER",
    "RESOA", "IEH", "PRE-K", "DCAS", "FY", "FAST TRACK PROJECTS"
]

df = df.map(lambda x: x.replace('PREK', 'PRE-K') if isinstance(x, str) else x)

# Columns to check for project types
columns_to_check = ['project_type', 'project_phase_planned_end_date']

# Apply the function to each row
df['project_type_split'] = df.apply(lambda row: find_keywords(row, columns_to_check, project_types), axis=1)

# Explode the list into separate rows
df_exploded = df.explode('project_type_split')

# Filter out rows where 'project_type_split' is NaN
df_exploded = df_exploded[df_exploded['project_type_split'].notna()]

# %%
# Checking for duplicate rows
duplicate_rows = df_exploded.duplicated().sum()

# Removing duplicate rows if any
df_cleaned = df_exploded.drop_duplicates()

duplicate_rows, df_cleaned.shape
# Out:
# (479, (5983, 15))

# %%
# Calculate the failure rate for each project type
failure_rate = df_cleaned.groupby('project_type_split')['failure'].mean()

# Sort the failure rate
failure_rate = failure_rate.sort_values(ascending=False)

# Bar chart
plt.figure(figsize=(12, 8))
failure_rate.plot(kind='bar', color='skyblue')
plt.title('Failure Rate by Project Type (where project status == "Complete")')
plt.xlabel('Project Type')
plt.ylabel('Failure Rate')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# %%
df_cleaned['dsf_number_s'] = df_cleaned['dsf_number_s'].str.replace('DSF: ', '')
df_cleaned['dsf_number_s'] = df_cleaned['dsf_number_s'].str.replace('DSF:', '')

df_cleaned
# Out:
# /var/folders/l7/rfx8sr1s2h32jhyxdrb33h_40000gn/T/ipykernel_8119/3745202402.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['dsf_number_s'] = df_cleaned['dsf_number_s'].str.replace('DSF: ', '')
# /var/folders/l7/rfx8sr1s2h32jhyxdrb33h_40000gn/T/ipykernel_8119/3745202402.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['dsf_number_s'] = df_cleaned['dsf_number_s'].str.replace('DSF:', '')
#       project_geographic_district project_building_identifier  \
# 2                              10                        X254
# 2                              10                        X254
# 2                              10                        X254
# 6                              10                        X254
# 6                              10                        X254
# ...                           ...                         ...
# 8176                           32                        K799
# 8177                           32                        K799
# 8177                           32                        K799
# 8181                           32                        K865
# 8181                           32                        K865
#
#          project_school_name   project_type  \
# 2           I.S. 254 - BRONX  SCA CIP RESOA
# 2           I.S. 254 - BRONX  SCA CIP RESOA
# 2           I.S. 254 - BRONX  SCA CIP RESOA
# 6           I.S. 254 - BRONX   DIIT - RESOA
# 6           I.S. 254 - BRONX   DIIT - RESOA
# ...                      ...            ...
# 8176  ALC - BROOKLYN CHOICES        SCA CIP
# 8177  ALC - BROOKLYN CHOICES        SCA CIP
# 8177  ALC - BROOKLYN CHOICES        SCA CIP
# 8181    BUSHWICK LEADERS - K        SCA CIP
# 8181    BUSHWICK LEADERS - K        SCA CIP
#
#                                   project_description project_phase_name  \
# 2     FY16 RESO A IP SURVEILLANCE CAMERA INSTALLATION              Scope
# 2     FY16 RESO A IP SURVEILLANCE CAMERA INSTALLATION              Scope
# 2     FY16 RESO A IP SURVEILLANCE CAMERA INSTALLATION              Scope
# 6                              FY17 RESO A TECHNOLOGY    Purch & Install
# 6                              FY17 RESO A TECHNOLOGY    Purch & Install
# ...                                               ...                ...
# 8176               EXT MASONRY/WINDOWS/PARAPETS/ROOFS              Scope
# 8177               EXT MASONRY/WINDOWS/PARAPETS/ROOFS             Design
# 8177               EXT MASONRY/WINDOWS/PARAPETS/ROOFS             Design
# 8181                         CERTIFICATE OF OCCUPANCY              Scope
# 8181                         CERTIFICATE OF OCCUPANCY              Scope
#
#      project_phase_actual_start_date project_phase_planned_end_date  \
# 2                         07/27/2017                     11/27/2017
# 2                         07/27/2017                     11/27/2017
# 2                         07/27/2017                     11/27/2017
# 6                         05/15/2017                     01/15/2018
# 6                         05/15/2017                     01/15/2018
# ...                              ...                            ...
# 8176                      08/10/2015                     12/28/2015
# 8177                      06/24/2016                     11/28/2016
# 8177                      06/24/2016                     11/28/2016
# 8181                      06/18/2013                     12/02/2013
# 8181                      06/18/2013                     12/02/2013
#
#      project_phase_actual_end_date project_budget_amount  \
# 2                       08/03/2017                     0
# 2                       08/03/2017                     0
# 2                       08/03/2017                     0
# 6                       09/14/2017                 50000
# 6                       09/14/2017                 50000
# ...                            ...                   ...
# 8176                    03/28/2016                 97918
# 8177                    02/07/2017                382688
# 8177                    02/07/2017                382688
# 8181                    11/18/2013                 93274
# 8181                    11/18/2013                 93274
#
#       final_estimate_of_actual_costs_through_end_of_phase_amount  \
# 2                                                1792.0
# 2                                                1792.0
# 2                                                1792.0
# 6                                               49625.0
# 6                                               49625.0
# ...                                                 ...
# 8176                                            90549.0
# 8177                                           366145.0
# 8177                                           366145.0
# 8181                                           124725.0
# 8181                                           124725.0
#
#       total_phase_actual_spending_amount  \
# 2                                 1792.0
# 2                                 1792.0
# 2                                 1792.0
# 6                                49625.0
# 6                                49625.0
# ...                                  ...
# 8176                             90549.0
# 8177                            312034.0
# 8177                            312034.0
# 8181                            118749.0
# 8181                            118749.0
#
#                                         dsf_number_s  failure  \
# 2                                         0000823560    False
# 2                                         0000823560    False
# 2                                         0000823560    False
# 6                                         0000844624    False
# 6                                         0000844624    False
# ...                                              ...      ...
# 8176  0000822169, 0000843221, 0000843222, 0000843223    False
# 8177  0000822169, 0000843221, 0000843222, 0000843223    False
# 8177  0000822169, 0000843221, 0000843222, 0000843223    False
# 8181                                      0000776207    False
# 8181                                      0000776207    False
#
#      project_type_split
# 2                   SCA
# 2                   CIP
# 2                 RESOA
# 6                  DIIT
# 6                 RESOA
# ...                 ...
# 8176                CIP
# 8177                SCA
# 8177                CIP
# 8181                SCA
# 8181                CIP
#
# [5983 rows x 15 columns]

# %%
# Split the 'numbers' column into a list of numbers
df_cleaned['dsf_number_s'] = df_cleaned['dsf_number_s'].str.split(', ')

# Explode the 'numbers' column so each row contains only one number
df_exploded = df_cleaned.explode('dsf_number_s').reset_index(drop=True)

df_exploded
# Out:
# /var/folders/l7/rfx8sr1s2h32jhyxdrb33h_40000gn/T/ipykernel_8119/1359706375.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['dsf_number_s'] = df_cleaned['dsf_number_s'].str.split(', ')
#       project_geographic_district project_building_identifier  \
# 0                              10                        X254
# 1                              10                        X254
# 2                              10                        X254
# 3                              10                        X254
# 4                              10                        X254
# ...                           ...                         ...
# 9142                           32                        K799
# 9143                           32                        K799
# 9144                           32                        K799
# 9145                           32                        K865
# 9146                           32                        K865
#
#          project_school_name   project_type  \
# 0           I.S. 254 - BRONX  SCA CIP RESOA
# 1           I.S. 254 - BRONX  SCA CIP RESOA
# 2           I.S. 254 - BRONX  SCA CIP RESOA
# 3           I.S. 254 - BRONX   DIIT - RESOA
# 4           I.S. 254 - BRONX   DIIT - RESOA
# ...                      ...            ...
# 9142  ALC - BROOKLYN CHOICES        SCA CIP
# 9143  ALC - BROOKLYN CHOICES        SCA CIP
# 9144  ALC - BROOKLYN CHOICES        SCA CIP
# 9145    BUSHWICK LEADERS - K        SCA CIP
# 9146    BUSHWICK LEADERS - K        SCA CIP
#
#                                   project_description project_phase_name  \
# 0     FY16 RESO A IP SURVEILLANCE CAMERA INSTALLATION              Scope
# 1     FY16 RESO A IP SURVEILLANCE CAMERA INSTALLATION              Scope
# 2     FY16 RESO A IP SURVEILLANCE CAMERA INSTALLATION              Scope
# 3                              FY17 RESO A TECHNOLOGY    Purch & Install
# 4                              FY17 RESO A TECHNOLOGY    Purch & Install
# ...                                               ...                ...
# 9142               EXT MASONRY/WINDOWS/PARAPETS/ROOFS             Design
# 9143               EXT MASONRY/WINDOWS/PARAPETS/ROOFS             Design
# 9144               EXT MASONRY/WINDOWS/PARAPETS/ROOFS             Design
# 9145                         CERTIFICATE OF OCCUPANCY              Scope
# 9146                         CERTIFICATE OF OCCUPANCY              Scope
#
#      project_phase_actual_start_date project_phase_planned_end_date  \
# 0                         07/27/2017                     11/27/2017
# 1                         07/27/2017                     11/27/2017
# 2                         07/27/2017                     11/27/2017
# 3                         05/15/2017                     01/15/2018
# 4                         05/15/2017                     01/15/2018
# ...                              ...                            ...
# 9142                      06/24/2016                     11/28/2016
# 9143                      06/24/2016                     11/28/2016
# 9144                      06/24/2016                     11/28/2016
# 9145                      06/18/2013                     12/02/2013
# 9146                      06/18/2013                     12/02/2013
#
#      project_phase_actual_end_date project_budget_amount  \
# 0                       08/03/2017                     0
# 1                       08/03/2017                     0
# 2                       08/03/2017                     0
# 3                       09/14/2017                 50000
# 4                       09/14/2017                 50000
# ...                            ...                   ...
# 9142                    02/07/2017                382688
# 9143                    02/07/2017                382688
# 9144                    02/07/2017                382688
# 9145                    11/18/2013                 93274
# 9146                    11/18/2013                 93274
#
#       final_estimate_of_actual_costs_through_end_of_phase_amount  \
# 0                                                1792.0
# 1                                                1792.0
# 2                                                1792.0
# 3                                               49625.0
# 4                                               49625.0
# ...                                                 ...
# 9142                                           366145.0
# 9143                                           366145.0
# 9144                                           366145.0
# 9145                                           124725.0
# 9146                                           124725.0
#
#       total_phase_actual_spending_amount dsf_number_s  failure  \
# 0                                 1792.0   0000823560    False
# 1                                 1792.0   0000823560    False
# 2                                 1792.0   0000823560    False
# 3                                49625.0   0000844624    False
# 4                                49625.0   0000844624    False
# ...                                  ...          ...      ...
# 9142                            312034.0   0000843221    False
# 9143                            312034.0   0000843222    False
# 9144                            312034.0   0000843223    False
# 9145                            118749.0   0000776207    False
# 9146                            118749.0   0000776207    False
#
#      project_type_split
# 0                   SCA
# 1                   CIP
# 2                 RESOA
# 3                  DIIT
# 4                 RESOA
# ...                 ...
# 9142                CIP
# 9143                CIP
# 9144                CIP
# 9145                SCA
# 9146                CIP
#
# [9147 rows x 15 columns]

# %%
# df_exploded = df_exploded[['project_phase_name', 'dsf_number_s']]

# %%
# # Checking for duplicate rows
# duplicate_rows = df_exploded.duplicated().sum()

# # Removing duplicate rows if any
# df_cleaned = df_exploded.drop_duplicates()

# duplicate_rows, df_cleaned.shape

# %%
get_unique_values_with_counts(df_exploded, 'dsf_number_s')
# Out:
# {'': 69,
#  '0000800354': 12,
#  '0000822761': 12,
#  '0000844816': 12,
#  '0000800349': 12,
#  '0000822618': 12,
#  '0000844240': 12,
#  '0000822337': 12,
#  '0000822848': 12,
#  '0000822329': 12,
#  '0000822326': 12,
#  '0000754751': 12,
#  '0000800452': 12,
#  '0000844204': 12,
#  '0000822317': 12,
#  '0000821686': 12,
#  '0000822882': 12,
#  '0000823595': 12,
#  '0000844887': 12,
#  '0000800028': 12,
#  '0000844931': 12,
#  '0000822782': 12,
#  '0000844194': 12,
#  '0000798846': 12,
#  '0000798733': 12,
#  '0000800389': 12,
#  '0000798683': 12,
#  '0000822322': 12,
#  '0000754616': 12,
#  '0000798833': 12,
#  '0000822621': 12,
#  '0000844220': 12,
#  '0000844228': 12,
#  '0000822872': 12,
#  '0000801018': 12,
#  '0000822890': 12,
#  '0000843811': 12,
#  '0000822735': 12,
#  '0000822886': 12,
#  '0000844969': 12,
#  '0000822715': 12,
#  '0000822812': 12,
#  '0000822905': 12,
#  '0000822825': 12,
#  '0000822752': 12,
#  '0000822316': 12,
#  '0000798195': 10,
#  '0000792877': 8,
#  '0000788303': 8,
#  '0000807157': 8,
#  '0000865836': 8,
#  '0000843890': 8,
#  '0000791457': 8,
#  '0000792874': 8,
#  '0000821932': 8,
#  '0000770166': 8,
#  '0000791453': 8,
#  '0000798618': 8,
#  '0000822206': 8,
#  '0000770165': 8,
#  '0000798617': 8,
#  '0000790733': 8,
#  '0000791458': 8,
#  '0000762772': 8,
#  '0000821657': 8,
#  '0000788306': 8,
#  '0000800060': 8,
#  '0000775650': 8,
#  '0000807155': 8,
#  '0000738909': 8,
#  '0000790253': 8,
#  '0000752879': 8,
#  '0000738908': 8,
#  '0000790252': 8,
#  '0000717681': 8,
#  '0000824866': 8,
#  '0000798639': 8,
#  '0000798638': 8,
#  '0000790250': 8,
#  '0000798637': 8,
#  '0000799435': 8,
#  '0000799931': 8,
#  '0000712839': 8,
#  '0000822154': 8,
#  '0000780969': 8,
#  '0000801048': 8,
#  '0000794184': 8,
#  '0000748526': 8,
#  '0000781022': 8,
#  '0000781029': 8,
#  '0000781030': 8,
#  '0000859712': 8,
#  '0000792471': 8,
#  '0000769753': 8,
#  '0000746804': 8,
#  '0000746802': 8,
#  '0000819319': 8,
#  '0000781046': 8,
#  '0000801070': 8,
#  '0000801023': 8,
#  '0000762786': 8,
#  '0000821804': 8,
#  '0000762771': 8,
#  '0000762773': 8,
#  '0000794183': 8,
#  '0000799946': 8,
#  '0000807302': 8,
#  '0000738911': 8,
#  '0000761374': 8,
#  '0000799436': 8,
#  '0000815965': 8,
#  '0000792734': 8,
#  '0000780973': 8,
#  '0000822176': 8,
#  '0000799532': 8,
#  '0000800332': 8,
#  '0000781814': 8,
#  '0000804911': 8,
#  '0000781813': 8,
#  '0000799939': 8,
#  '0000843656': 8,
#  '0000800331': 8,
#  '0000826670': 8,
#  '0000799905': 8,
#  '0000799904': 8,
#  '0000799903': 8,
#  '0000800283': 8,
#  '0000738916': 8,
#  '0000738917': 8,
#  '0000717814': 8,
#  '0000026654': 8,
#  '0000780676': 8,
#  '0000799793': 8,
#  '0000799794': 8,
#  '0000798244': 8,
#  '0000798245': 8,
#  '0000821931': 8,
#  '0000767810': 8,
#  '0000767813': 8,
#  '0000799423': 8,
#  '0000767826': 8,
#  '0000775971': 8,
#  '0000839997': 8,
#  '0000777687': 8,
#  '0000798274': 8,
#  '0000788791': 8,
#  '0000790816': 8,
#  '0000799419': 8,
#  '0000799421': 8,
#  '0000739062': 8,
#  '0000028933': 8,
#  '0000844050': 8,
#  '0000802235': 8,
#  '0000026417': 8,
#  '0000795966': 8,
#  '0000799880': 8,
#  '0000799881': 8,
#  '0000761351': 8,
#  '0000783974': 8,
#  '0000783975': 8,
#  '0000783976': 8,
#  '0000843909': 8,
#  '0000843816': 8,
#  '0000821805': 8,
#  '0000753048': 8,
#  '0000765244': 8,
#  '0000765245': 8,
#  '0000819760': 8,
#  '0000822188': 8,
#  '0000765246': 8,
#  '0000821912': 8,
#  '0000802236': 8,
#  '0000799422': 8,
#  '0000767812': 8,
#  '0000710245': 8,
#  '0000777440': 8,
#  '0000778354': 8,
#  '0000777709': 8,
#  '0000796075': 8,
#  '0000821872': 8,
#  '0000778318': 8,
#  '0000710254': 8,
#  '0000819267': 8,
#  '0000821809': 8,
#  '0000763744': 8,
#  '0000799784': 8,
#  '0000763743': 8,
#  '0000763742': 8,
#  '0000802044': 8,
#  '0000024913': 8,
#  '0000799577': 8,
#  '0000775578': 8,
#  '0000761860': 8,
#  '0000761845': 8,
#  '0000821682': 8,
#  '0000819265': 8,
#  '0000791459': 8,
#  '0000710359': 8,
#  '0000756107': 8,
#  '0000756105': 8,
#  '0000733307': 8,
#  '0000775792': 8,
#  '0000821818': 8,
#  '0000756109': 8,
#  '0000780092': 8,
#  '0000801839': 8,
#  '0000843904': 7,
#  '0000844879': 6,
#  '0000777343': 6,
#  '0000823562': 6,
#  '0000822852': 6,
#  '0000844935': 6,
#  '0000822889': 6,
#  '0000822895': 6,
#  '0000798208': 6,
#  '0000844983': 6,
#  '0000844941': 6,
#  '0000843960': 6,
#  '0000822746': 6,
#  '0000844859': 6,
#  '0000844880': 6,
#  '0000798679': 6,
#  '0000844973': 6,
#  '0000844798': 6,
#  '0000822898': 6,
#  '0000844896': 6,
#  '0000731617': 6,
#  '0000754719': 6,
#  '0000844171': 6,
#  '0000844877': 6,
#  '0000822733': 6,
#  '0000844806': 6,
#  '0000798828': 6,
#  '0000822884': 6,
#  '0000798744': 6,
#  '0000800481': 6,
#  '0000821937': 6,
#  '0000710805': 6,
#  '0000845157': 6,
#  '0000800408': 6,
#  '0000822348': 6,
#  '0000844832': 6,
#  '0000844905': 6,
#  '0000822883': 6,
#  '0000844993': 6,
#  '0000843649': 6,
#  '0000844902': 6,
#  '0000800361': 6,
#  '0000844840': 6,
#  '0000844198': 6,
#  '0000844200': 6,
#  '0000865725': 6,
#  '0000800477': 6,
#  '0000844872': 6,
#  '0000800501': 6,
#  '0000822734': 6,
#  '0000754658': 6,
#  '0000754744': 6,
#  '0000798665': 6,
#  '0000798670': 6,
#  '0000844109': 6,
#  '0000844110': 6,
#  '0000823147': 6,
#  '0000822856': 6,
#  '0000800096': 6,
#  '0000822332': 6,
#  '0000821871': 6,
#  '0000798856': 6,
#  '0000866317': 6,
#  '0000844231': 6,
#  '0000843833': 6,
#  '0000822855': 6,
#  '0000754508': 6,
#  '0000731083': 6,
#  '0000844814': 6,
#  '0000800089': 6,
#  '0000844229': 6,
#  '0000800027': 6,
#  '0000844984': 6,
#  '0000800367': 6,
#  '0000822346': 6,
#  '0000844797': 6,
#  '0000822770': 6,
#  '0000822181': 6,
#  '0000800742': 6,
#  '0000800343': 6,
#  '0000798753': 6,
#  '0000823548': 6,
#  '0000798196': 6,
#  '0000822304': 6,
#  '0000822352': 6,
#  '0000844173': 6,
#  '0000866745': 6,
#  '0000844785': 6,
#  '0000798655': 6,
#  '0000798178': 6,
#  '0000844786': 6,
#  '0000844895': 6,
#  '0000822778': 6,
#  '0000799338': 6,
#  '0000844787': 6,
#  '0000776001': 6,
#  '0000800366': 6,
#  '0000844899': 6,
#  '0000823110': 6,
#  '0000822336': 6,
#  '0000822274': 6,
#  '0000844834': 6,
#  '0000822899': 6,
#  '0000844223': 6,
#  '0000801036': 6,
#  '0000822276': 6,
#  '0000844852': 6,
#  '0000822818': 6,
#  '0000823558': 6,
#  '0000843950': 6,
#  '0000822345': 6,
#  '0000844928': 6,
#  '0000844221': 6,
#  '0000822888': 6,
#  '0000844957': 6,
#  '0000844982': 6,
#  '0000822774': 6,
#  '0000710869': 6,
#  '0000798182': 5,
#  '0000798193': 5,
#  '0000821799': 5,
#  '0000798189': 5,
#  '0000814735': 4,
#  '0000864012': 4,
#  '0000843855': 4,
#  '0000838987': 4,
#  '0000728491': 4,
#  '0000795504': 4,
#  '0000799991': 4,
#  '0000855949': 4,
#  '0000844688': 4,
#  '0000842000': 4,
#  '0000784059': 4,
#  '0000844753': 4,
#  '0000839643': 4,
#  '0000843772': 4,
#  '0000788585': 4,
#  '0000811905': 4,
#  '0000811906': 4,
#  '0000786449': 4,
#  '0000786456': 4,
#  '0000799887': 4,
#  '0000818364': 4,
#  '0000853820': 4,
#  '0000800334': 4,
#  '0000811907': 4,
#  '0000732406': 4,
#  '0000844751': 4,
#  '0000844752': 4,
#  '0000855950': 4,
#  '0000812532': 4,
#  '0000867019': 4,
#  '0000844014': 4,
#  '0000798382': 4,
#  '0000799754': 4,
#  '0000797940': 4,
#  '0000843694': 4,
#  '0000843978': 4,
#  '0000798205': 4,
#  '0000798301': 4,
#  '0000839282': 4,
#  '0000797939': 4,
#  '0000793656': 4,
#  '0000866744': 4,
#  '0000865726': 4,
#  '0000789251': 4,
#  '0000844015': 4,
#  '0000791100': 4,
#  '0000789257': 4,
#  '0000822270': 4,
#  '0000799426': 4,
#  '0000843851': 4,
#  '0000843985': 4,
#  '0000821803': 4,
#  '0000752357': 4,
#  '0000839644': 4,
#  '0000816873': 4,
#  '0000793663': 4,
#  '0000816860': 4,
#  '0000798318': 4,
#  '0000816867': 4,
#  '0000798315': 4,
#  '0000821892': 4,
#  '0000864303': 4,
#  '0000856554': 4,
#  '0000789244': 4,
#  '0000822228': 4,
#  '0000789250': 4,
#  '0000843860': 4,
#  '0000822118': 4,
#  '0000797941': 4,
#  '0000752356': 4,
#  '0000818363': 4,
#  '0000788293': 4,
#  '0000839645': 4,
#  '0000799608': 4,
#  '0000808179': 4,
#  '0000808180': 4,
#  '0000822005': 4,
#  '0000822121': 4,
#  '0000822122': 4,
#  '0000830259': 4,
#  '0000783287': 4,
#  '0000821636': 4,
#  '0000808952': 4,
#  '0000799402': 4,
#  '0000783269': 4,
#  '0000783265': 4,
#  '0000737755': 4,
#  '0000808951': 4,
#  '0000030133': 4,
#  '0000785119': 4,
#  '0000808949': 4,
#  '0000799919': 4,
#  '0000799439': 4,
#  '0000737753': 4,
#  '0000808176': 4,
#  '0000783273': 4,
#  '0000788296': 4,
#  '0000865813': 4,
#  '0000788302': 4,
#  '0000783272': 4,
#  '0000841657': 4,
#  '0000809493': 4,
#  '0000799428': 4,
#  '0000841659': 4,
#  '0000865776': 4,
#  '0000027056': 4,
#  '0000799438': 4,
#  '0000027593': 4,
#  '0000796822': 4,
#  '0000783284': 4,
#  '0000799351': 4,
#  '0000783270': 4,
#  '0000801088': 4,
#  '0000843844': 4,
#  '0000839646': 4,
#  '0000818851': 4,
#  '0000817970': 4,
#  '0000794783': 4,
#  '0000818199': 4,
#  '0000795506': 4,
#  '0000811759': 4,
#  '0000861725': 4,
#  '0000822673': 4,
#  '0000822674': 4,
#  '0000795505': 4,
#  '0000822675': 4,
#  '0000821948': 4,
#  '0000821949': 4,
#  '0000807364': 4,
#  '0000843892': 4,
#  '0000822173': 4,
#  '0000786448': 4,
#  '0000822676': 4,
#  '0000821923': 4,
#  '0000821908': 4,
#  '0000808720': 4,
#  '0000799406': 4,
#  '0000783260': 4,
#  '0000798565': 4,
#  '0000755235': 4,
#  '0000799403': 4,
#  '0000843652': 4,
#  '0000804821': 4,
#  '0000799876': 4,
#  '0000423946': 4,
#  '0000798374': 4,
#  '0000792110': 4,
#  '0000844039': 4,
#  '0000844006': 4,
#  '0000423947': 4,
#  '0000799404': 4,
#  '0000030993': 4,
#  '0000800327': 4,
#  '0000799405': 4,
#  '0000024953': 4,
#  '0000721890': 4,
#  '0000752358': 4,
#  '0000780635': 4,
#  '0000790584': 4,
#  '0000798371': 4,
#  '0000826853': 4,
#  '0000826850': 4,
#  '0000822269': 4,
#  '0000780632': 4,
#  '0000780634': 4,
#  '0000826031': 4,
#  '0000822123': 4,
#  '0000826023': 4,
#  '0000826018': 4,
#  '0000803605': 4,
#  '0000780281': 4,
#  '0000800109': 4,
#  '0000735418': 4,
#  '0000735420': 4,
#  '0000845578': 4,
#  '0000791664': 4,
#  '0000814902': 4,
#  '0000814904': 4,
#  '0000799911': 4,
#  '0000769320': 4,
#  '0000769311': 4,
#  '0000769310': 4,
#  '0000769305': 4,
#  '0000769303': 4,
#  '0000780173': 4,
#  '0000825915': 4,
#  '0000825919': 4,
#  '0000844157': 4,
#  '0000780265': 4,
#  '0000768897': 4,
#  '0000745990': 4,
#  '0000822192': 4,
#  '0000814906': 4,
#  '0000735421': 4,
#  '0000865787': 4,
#  '0000865785': 4,
#  '0000801066': 4,
#  '0000783448': 4,
#  '0000843951': 4,
#  '0000790753': 4,
#  '0000798297': 4,
#  '0000745395': 4,
#  '0000812865': 4,
#  '0000814327': 4,
#  '0000814328': 4,
#  '0000821858': 4,
#  '0000745480': 4,
#  '0000866094': 4,
#  '0000813349': 4,
#  '0000813348': 4,
#  '0000813347': 4,
#  '0000790055': 4,
#  '0000775948': 4,
#  '0000798566': 4,
#  '0000758297': 4,
#  '0000782731': 4,
#  '0000758299': 4,
#  '0000845902': 4,
#  '0000823812': 4,
#  '0000761724': 4,
#  '0000807062': 4,
#  '0000758723': 4,
#  '0000781917': 4,
#  '0000805209': 4,
#  '0000829300': 4,
#  '0000843850': 4,
#  '0000821683': 4,
#  '0000798278': 4,
#  '0000798281': 4,
#  '0000843849': 4,
#  '0000821933': 4,
#  '0000799912': 4,
#  '0000822124': 4,
#  '0000752359': 4,
#  '0000843865': 4,
#  '0000769206': 4,
#  '0000791972': 4,
#  '0000799902': 4,
#  '0000815270': 4,
#  '0000815282': 4,
#  '0000815284': 4,
#  '0000843655': 4,
#  '0000814110': 4,
#  '0000822125': 4,
#  '0000765327': 4,
#  '0000866320': 4,
#  '0000866090': 4,
#  '0000866089': 4,
#  '0000857427': 4,
#  '0000787947': 4,
#  '0000865781': 4,
#  '0000769202': 4,
#  '0000769191': 4,
#  '0000782401': 4,
#  '0000805706': 4,
#  '0000866743': 4,
#  '0000844698': 4,
#  '0000783396': 4,
#  '0000843846': 4,
#  '0000865804': 4,
#  '0000844747': 4,
#  '0000843861': 4,
#  '0000858912': 4,
#  '0000769187': 4,
#  '0000769189': 4,
#  '0000844016': 4,
#  '0000865798': 4,
#  '0000865799': 4,
#  '0000769190': 4,
#  '0000822187': 4,
#  '0000822081': 4,
#  '0000730986': 4,
#  '0000756089': 4,
#  '0000798260': 4,
#  '0000779335': 4,
#  '0000844152': 4,
#  '0000833966': 4,
#  '0000833964': 4,
#  '0000779337': 4,
#  '0000837609': 4,
#  '0000779340': 4,
#  '0000844158': 4,
#  '0000837585': 4,
#  '0000859513': 4,
#  '0000821810': 4,
#  '0000815507': 4,
#  '0000792257': 4,
#  '0000792256': 4,
#  '0000843935': 4,
#  '0000743071': 4,
#  '0000766068': 4,
#  '0000812371': 4,
#  '0000766069': 4,
#  '0000812370': 4,
#  '0000789066': 4,
#  '0000789064': 4,
#  '0000778565': 4,
#  '0000778566': 4,
#  '0000802608': 4,
#  '0000825073': 4,
#  '0000825075': 4,
#  '0000712695': 4,
#  '0000844057': 4,
#  '0000802628': 4,
#  '0000802630': 4,
#  '0000802631': 4,
#  '0000798257': 4,
#  '0000878637': 4,
#  '0000799467': 4,
#  '0000798276': 4,
#  '0000789941': 4,
#  '0000818176': 4,
#  '0000795070': 4,
#  '0000795069': 4,
#  '0000795068': 4,
#  '0000795066': 4,
#  '0000822175': 4,
#  '0000818181': 4,
#  '0000818178': 4,
#  '0000794989': 4,
#  '0000783461': 4,
#  '0000866083': 4,
#  '0000866082': 4,
#  '0000862039': 4,
#  '0000862038': 4,
#  '0000780542': 4,
#  '0000752872': 4,
#  '0000832371': 4,
#  '0000821925': 4,
#  '0000822174': 4,
#  '0000866261': 4,
#  '0000843822': 4,
#  '0000798326': 4,
#  '0000789227': 4,
#  '0000821893': 4,
#  '0000822164': 4,
#  '0000821891': 4,
#  '0000795617': 4,
#  '0000798368': 4,
#  '0000795268': 4,
#  '0000795267': 4,
#  '0000836272': 4,
#  '0000836273': 4,
#  '0000836274': 4,
#  '0000836276': 4,
#  '0000847312': 4,
#  '0000847313': 4,
#  '0000810292': 4,
#  '0000843852': 4,
#  '0000821658': 4,
#  '0000798269': 4,
#  '0000799938': 4,
#  '0000777290': 4,
#  '0000777289': 4,
#  '0000753130': 4,
#  '0000804352': 4,
#  '0000822685': 4,
#  '0000826760': 4,
#  '0000735855': 4,
#  '0000794346': 4,
#  '0000794345': 4,
#  '0000794344': 4,
#  '0000794342': 4,
#  '0000758754': 4,
#  '0000758755': 4,
#  '0000775945': 4,
#  '0000798268': 4,
#  '0000853963': 4,
#  '0000799953': 4,
#  '0000804351': 4,
#  '0000799952': 4,
#  '0000786994': 4,
#  '0000786993': 4,
#  '0000764372': 4,
#  '0000675235': 4,
#  '0000780543': 4,
#  '0000780545': 4,
#  '0000780550': 4,
#  '0000780560': 4,
#  '0000780563': 4,
#  '0000798612': 4,
#  '0000786770': 4,
#  '0000786769': 4,
#  '0000786768': 4,
#  '0000804350': 4,
#  '0000798327': 4,
#  '0000798293': 4,
#  '0000790486': 4,
#  '0000777692': 4,
#  '0000777689': 4,
#  '0000777688': 4,
#  '0000759677': 4,
#  '0000026515': 4,
#  '0000779171': 4,
#  '0000779172': 4,
#  '0000798253': 4,
#  '0000781767': 4,
#  '0000799530': 4,
#  '0000800273': 4,
#  '0000843651': 4,
#  '0000843650': 4,
#  '0000827141': 4,
#  '0000804745': 4,
#  '0000833494': 4,
#  '0000777691': 4,
#  '0000782243': 4,
#  '0000866156': 4,
#  '0000782256': 4,
#  '0000665737': 4,
#  '0000799401': 4,
#  '0000783669': 4,
#  '0000829210': 4,
#  '0000829213': 4,
#  '0000829257': 4,
#  '0000806993': 4,
#  '0000761082': 4,
#  '0000829214': 4,
#  '0000843845': 4,
#  '0000821958': 4,
#  '0000829999': 4,
#  '0000799884': 4,
#  '0000799883': 4,
#  '0000799882': 4,
#  '0000833495': 4,
#  '0000752401': 4,
#  '0000821031': 4,
#  '0000787330': 4,
#  '0000798279': 4,
#  '0000798280': 4,
#  '0000753035': 4,
#  '0000753034': 4,
#  '0000741699': 4,
#  '0000710960': 4,
#  '0000687155': 4,
#  '0000834789': 4,
#  '0000832617': 4,
#  '0000810567': 4,
#  '0000787251': 4,
#  '0000834790': 4,
#  '0000798369': 4,
#  '0000798370': 4,
#  '0000822210': 4,
#  '0000787328': 4,
#  '0000832702': 4,
#  '0000741840': 4,
#  '0000810662': 4,
#  '0000687120': 4,
#  '0000610028': 4,
#  '0000610019': 4,
#  '0000833496': 4,
#  '0000833500': 4,
#  '0000843954': 4,
#  '0000843955': 4,
#  '0000844141': 4,
#  '0000844140': 4,
#  '0000810708': 4,
#  '0000752355': 4,
#  '0000752354': 4,
#  '0000788635': 4,
#  '0000800280': 4,
#  '0000822211': 4,
#  '0000799444': 4,
#  '0000888808': 4,
#  '0000822165': 4,
#  '0000834091': 4,
#  '0000820925': 4,
#  '0000814742': 4,
#  '0000822240': 4,
#  '0000814748': 4,
#  '0000822213': 4,
#  '0000822096': 4,
#  '0000866757': 4,
#  '0000776000': 4,
#  '0000856028': 4,
#  '0000865950': 4,
#  '0000865951': 4,
#  '0000803089': 4,
#  '0000779760': 4,
#  '0000803030': 4,
#  '0000798339': 4,
#  '0000798341': 4,
#  '0000831121': 4,
#  '0000844074': 4,
#  '0000800111': 4,
#  '0000785833': 4,
#  '0000797701': 4,
#  '0000843847': 4,
#  '0000843949': 4,
#  '0000828992': 4,
#  '0000828991': 4,
#  '0000828990': 4,
#  '0000828988': 4,
#  '0000798298': 4,
#  '0000783145': 4,
#  '0000798262': 4,
#  '0000798261': 4,
#  '0000803029': 4,
#  '0000803027': 4,
#  '0000779700': 4,
#  '0000798389': 4,
#  '0000843918': 4,
#  '0000822179': 4,
#  '0000859681': 4,
#  '0000815645': 4,
#  '0000844118': 4,
#  '0000844117': 4,
#  '0000826871': 4,
#  '0000804479': 4,
#  '0000808442': 4,
#  '0000830519': 4,
#  '0000830599': 4,
#  '0000830600': 4,
#  '0000830601': 4,
#  '0000852590': 4,
#  '0000798396': 4,
#  '0000803013': 4,
#  '0000775609': 4,
#  '0000775610': 4,
#  '0000843678': 4,
#  '0000851379': 4,
#  '0000851378': 4,
#  '0000851377': 4,
#  '0000851375': 4,
#  '0000807257': 4,
#  '0000802950': 4,
#  '0000825393': 4,
#  '0000825394': 4,
#  '0000843697': 4,
#  '0000779686': 4,
#  '0000803012': 4,
#  '0000827389': 4,
#  '0000798267': 4,
#  '0000849017': 4,
#  '0000782597': 4,
#  '0000785880': 4,
#  '0000789420': 4,
#  '0000789417': 4,
#  '0000766746': 4,
#  '0000803545': 4,
#  '0000803544': 4,
#  '0000780227': 4,
#  '0000764102': 4,
#  '0000803429': 4,
#  '0000829074': 4,
#  '0000845614': 4,
#  '0000805894': 4,
#  '0000854533': 4,
#  '0000888807': 4,
#  '0000788417': 4,
#  '0000812976': 4,
#  '0000851535': 4,
#  '0000867176': 4,
#  '0000822167': 4,
#  '0000844164': 4,
#  '0000865816': 4,
#  '0000788418': 4,
#  '0000761629': 4,
#  '0000775989': 4,
#  '0000784298': 4,
#  '0000784302': 4,
#  '0000807595': 4,
#  '0000807596': 4,
#  '0000807597': 4,
#  '0000844042': 4,
#  '0000800108': 4,
#  '0000812977': 4,
#  '0000781711': 4,
#  '0000835909': 4,
#  '0000798593': 4,
#  '0000844012': 4,
#  '0000826342': 4,
#  '0000803935': 4,
#  '0000800269': 4,
#  '0000806120': 4,
#  '0000844112': 4,
#  '0000844111': 4,
#  '0000835911': 4,
#  '0000828583': 4,
#  '0000850482': 4,
#  '0000850484': 4,
#  '0000850485': 4,
#  '0000783558': 4,
#  '0000821590': 4,
#  '0000812978': 4,
#  '0000777287': 4,
#  '0000851197': 4,
#  '0000010242': 4,
#  '0000843953': 4,
#  '0000752882': 4,
#  '0000784010': 4,
#  '0000799355': 4,
#  '0000784014': 4,
#  '0000784033': 4,
#  '0000857031': 4,
#  '0000822214': 4,
#  '0000857030': 4,
#  '0000857028': 4,
#  '0000835085': 4,
#  '0000843919': 4,
#  '0000775995': 4,
#  '0000833628': 4,
#  '0000775608': 4,
#  '0000777221': 4,
#  '0000777261': 4,
#  '0000865809': 4,
#  '0000843677': 4,
#  '0000838676': 4,
#  '0000822215': 4,
#  '0000775607': 4,
#  '0000775994': 4,
#  '0000785205': 4,
#  '0000802752': 4,
#  '0000821904': 4,
#  '0000847155': 4,
#  '0000832931': 4,
#  '0000821944': 4,
#  '0000799534': 4,
#  '0000770719': 4,
#  '0000770718': 4,
#  '0000770715': 4,
#  '0000770711': 4,
#  '0000025015': 4,
#  '0000751712': 4,
#  '0000797406': 4,
#  '0000797407': 4,
#  '0000797408': 4,
#  '0000797414': 4,
#  '0000770710': 4,
#  '0000843972': 4,
#  '0000866166': 4,
#  '0000866177': 4,
#  '0000770707': 4,
#  '0000770705': 4,
#  '0000844680': 4,
#  '0000622222': 4,
#  '0000752880': 4,
#  '0000843676': 4,
#  '0000843223': 4,
#  '0000820035': 4,
#  '0000866151': 4,
#  '0000843222': 4,
#  '0000843221': 4,
#  '0000799913': 4,
#  '0000775984': 4,
#  '0000843858': 4,
#  '0000774339': 4,
#  '0000774340': 4,
#  '0000774341': 4,
#  '0000775991': 4,
#  '0000843859': 4,
#  '0000822169': 4,
#  '0000754569': 4,
#  '0000820386': 4,
#  '0000797100': 4,
#  '0000798647': 4,
#  '0000821913': 4,
#  '0000774374': 4,
#  '0000822032': 4,
#  '0000820291': 4,
#  '0000822171': 4,
#  '0000864171': 4,
#  '0000866263': 4,
#  '0000851041': 4,
#  '0000829162': 4,
#  '0000797229': 4,
#  '0000820383': 4,
#  '0000820385': 4,
#  '0000732118': 4,
#  '0000752360': 4,
#  '0000752361': 4,
#  '0000752364': 4,
#  '0000801024': 4,
#  ...}

# %%
df_exploded[df_exploded['dsf_number_s'] == '0000822169']
df_exploded[df_exploded['dsf_number_s'] == '0000843221']
df_exploded[df_exploded['dsf_number_s'] == '0000843222']

# df_exploded[df_exploded['project_phase_name'] == 'Design']
# Out:
#       project_geographic_district project_building_identifier  \
# 9131                           32                        K799
# 9135                           32                        K799
# 9139                           32                        K799
# 9143                           32                        K799
#
#          project_school_name project_type                 project_description  \
# 9131  ALC - BROOKLYN CHOICES      SCA CIP  EXT MASONRY/WINDOWS/PARAPETS/ROOFS
# 9135  ALC - BROOKLYN CHOICES      SCA CIP  EXT MASONRY/WINDOWS/PARAPETS/ROOFS
# 9139  ALC - BROOKLYN CHOICES      SCA CIP  EXT MASONRY/WINDOWS/PARAPETS/ROOFS
# 9143  ALC - BROOKLYN CHOICES      SCA CIP  EXT MASONRY/WINDOWS/PARAPETS/ROOFS
#
#      project_phase_name project_phase_actual_start_date  \
# 9131              Scope                      08/10/2015
# 9135              Scope                      08/10/2015
# 9139             Design                      06/24/2016
# 9143             Design                      06/24/2016
#
#      project_phase_planned_end_date project_phase_actual_end_date  \
# 9131                     12/28/2015                    03/28/2016
# 9135                     12/28/2015                    03/28/2016
# 9139                     11/28/2016                    02/07/2017
# 9143                     11/28/2016                    02/07/2017
#
#      project_budget_amount  \
# 9131                 97918
# 9135                 97918
# 9139                382688
# 9143                382688
#
#       final_estimate_of_actual_costs_through_end_of_phase_amount  \
# 9131                                            90549.0
# 9135                                            90549.0
# 9139                                           366145.0
# 9143                                           366145.0
#
#       total_phase_actual_spending_amount dsf_number_s  failure  \
# 9131                             90549.0   0000843222    False
# 9135                             90549.0   0000843222    False
# 9139                            312034.0   0000843222    False
# 9143                            312034.0   0000843222    False
#
#      project_type_split
# 9131                SCA
# 9135                CIP
# 9139                SCA
# 9143                CIP

# %%
df[df['dsf_number_s'].str.contains('0000822169')]
# df[df['dsf_number_s'].str.contains('0000843221')]
# df[df['dsf_number_s'].str.contains('0000843222')]
# Out:
#       project_geographic_district project_building_identifier  \
# 8176                           32                        K799
# 8177                           32                        K799
#
#          project_school_name project_type                 project_description  \
# 8176  ALC - BROOKLYN CHOICES      SCA CIP  EXT MASONRY/WINDOWS/PARAPETS/ROOFS
# 8177  ALC - BROOKLYN CHOICES      SCA CIP  EXT MASONRY/WINDOWS/PARAPETS/ROOFS
#
#      project_phase_name project_phase_actual_start_date  \
# 8176              Scope                      08/10/2015
# 8177             Design                      06/24/2016
#
#      project_phase_planned_end_date project_phase_actual_end_date  \
# 8176                     12/28/2015                    03/28/2016
# 8177                     11/28/2016                    02/07/2017
#
#      project_budget_amount  \
# 8176                 97918
# 8177                382688
#
#       final_estimate_of_actual_costs_through_end_of_phase_amount  \
# 8176                                            90549.0
# 8177                                           366145.0
#
#       total_phase_actual_spending_amount  \
# 8176                             90549.0
# 8177                            312034.0
#
#                                            dsf_number_s  failure  \
# 8176  DSF: 0000822169, 0000843221, 0000843222, 00008...    False
# 8177  DSF: 0000822169, 0000843221, 0000843222, 00008...    False
#
#      project_type_split
# 8176         [SCA, CIP]
# 8177         [SCA, CIP]

# %%
df
# Out:
#       project_geographic_district project_building_identifier  \
# 2                              10                        X254
# 6                              10                        X254
# 7                              10                        X254
# 8                              10                        X279
# 9                              10                        X279
# ...                           ...                         ...
# 8172                           32                        K677
# 8173                           32                        K677
# 8176                           32                        K799
# 8177                           32                        K799
# 8181                           32                        K865
#
#          project_school_name          project_type  \
# 2           I.S. 254 - BRONX         SCA CIP RESOA
# 6           I.S. 254 - BRONX          DIIT - RESOA
# 7           I.S. 254 - BRONX          DIIT - RESOA
# 8           P.S. 279 - BRONX               SCA CIP
# 9           P.S. 279 - BRONX               SCA CIP
# ...                      ...                   ...
# 8172     P.S. 677 - BROOKLYN  SCA Lease Site Impro
# 8173     P.S. 677 - BROOKLYN  SCA Lease Site Impro
# 8176  ALC - BROOKLYN CHOICES               SCA CIP
# 8177  ALC - BROOKLYN CHOICES               SCA CIP
# 8181    BUSHWICK LEADERS - K               SCA CIP
#
#                                   project_description project_phase_name  \
# 2     FY16 RESO A IP SURVEILLANCE CAMERA INSTALLATION              Scope
# 6                              FY17 RESO A TECHNOLOGY    Purch & Install
# 7                              FY17 RESO A TECHNOLOGY    Purch & Install
# 8                             WATER PENETRATION/ROOFS              Scope
# 9                             WATER PENETRATION/ROOFS             Design
# ...                                               ...                ...
# 8172                                            LEASE       Construction
# 8173                                            LEASE            CM, F&E
# 8176               EXT MASONRY/WINDOWS/PARAPETS/ROOFS              Scope
# 8177               EXT MASONRY/WINDOWS/PARAPETS/ROOFS             Design
# 8181                         CERTIFICATE OF OCCUPANCY              Scope
#
#      project_phase_actual_start_date project_phase_planned_end_date  \
# 2                         07/27/2017                     11/27/2017
# 6                         05/15/2017                     01/15/2018
# 7                         05/15/2017                     01/15/2018
# 8                         08/02/2016                     12/19/2016
# 9                         05/15/2017                     10/16/2017
# ...                              ...                            ...
# 8172                      12/05/2016                     12/04/2017
# 8173                      12/05/2016                     12/04/2017
# 8176                      08/10/2015                     12/28/2015
# 8177                      06/24/2016                     11/28/2016
# 8181                      06/18/2013                     12/02/2013
#
#      project_phase_actual_end_date project_budget_amount  \
# 2                       08/03/2017                     0
# 6                       09/14/2017                 50000
# 7                       09/14/2017                 76250
# 8                       02/13/2017                 36881
# 9                       12/18/2017                141246
# ...                            ...                   ...
# 8172                    08/11/2017               3551130
# 8173                    08/11/2017                500070
# 8176                    03/28/2016                 97918
# 8177                    02/07/2017                382688
# 8181                    11/18/2013                 93274
#
#       final_estimate_of_actual_costs_through_end_of_phase_amount  \
# 2                                                1792.0
# 6                                               49625.0
# 7                                               75677.0
# 8                                               57074.0
# 9                                              183396.0
# ...                                                 ...
# 8172                                          3563765.0
# 8173                                           406735.0
# 8176                                            90549.0
# 8177                                           366145.0
# 8181                                           124725.0
#
#       total_phase_actual_spending_amount  \
# 2                                 1792.0
# 6                                49625.0
# 7                                75677.0
# 8                                56288.0
# 9                               180358.0
# ...                                  ...
# 8172                           3377235.0
# 8173                            374706.0
# 8176                             90549.0
# 8177                            312034.0
# 8181                            118749.0
#
#                                            dsf_number_s  failure  \
# 2                                       DSF: 0000823560    False
# 6                                       DSF: 0000844624    False
# 7                                       DSF: 0000845571    False
# 8                           DSF: 0000820035, 0000866151    False
# 9                           DSF: 0000820035, 0000866151    False
# ...                                                 ...      ...
# 8172                                    DSF: 0000843676    False
# 8173                                    DSF: 0000843676    False
# 8176  DSF: 0000822169, 0000843221, 0000843222, 00008...    False
# 8177  DSF: 0000822169, 0000843221, 0000843222, 00008...    False
# 8181                                    DSF: 0000776207    False
#
#      project_type_split
# 2     [SCA, CIP, RESOA]
# 6         [DIIT, RESOA]
# 7         [DIIT, RESOA]
# 8            [SCA, CIP]
# 9            [SCA, CIP]
# ...                 ...
# 8172              [SCA]
# 8173              [SCA]
# 8176         [SCA, CIP]
# 8177         [SCA, CIP]
# 8181         [SCA, CIP]
#
# [2981 rows x 15 columns]

# %%
df_exploded.to_csv('complete_exploded.csv', index=False)
